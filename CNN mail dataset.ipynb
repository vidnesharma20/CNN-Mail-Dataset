# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib as plt

# %%
train_df = pd.read_csv("train.csv.zip")
train_df
# Out:
#                                               id  \
# 0       0001d1afc246a7964130f43ae940af6bc6c57f01
# 1       0002095e55fcbd3a2f366d9bf92a95433dc305ef
# 2       00027e965c8264c35cc1bc55556db388da82b07f
# 3       0002c17436637c4fe1837c935c04de47adb18e9a
# 4       0003ad6ef0c37534f80b55b4235108024b407f0b
# ...                                          ...
# 287108  fffdfb56fdf1a12d364562cc2b9b1d4de7481dee
# 287109  fffeecb8690b85de8c3faed80adbc7a978f9ae2a
# 287110  ffff5231e4c71544bc6c97015cdb16c60e42b3f4
# 287111  ffff924b14a8d82058b6c1c5368ff1113c1632af
# 287112  ffffd563a96104f5cf4493cfa701a65f31b06abf
#
#                                                   article  \
# 0       By . Associated Press . PUBLISHED: . 14:11 EST...
# 1       (CNN) -- Ralph Mata was an internal affairs li...
# 2       A drunk driver who killed a young woman in a h...
# 3       (CNN) -- With a breezy sweep of his pen Presid...
# 4       Fleetwood are the only team still to have a 10...
# ...

# %%
test_df = pd.read_csv("test.csv.zip")
test_df.head(10)
# Out:
#                                          id  \
# 0  92c514c913c0bdfe25341af9fd72b29db544099b
# 1  2003841c7dc0e7c5b1a248f9cd536d727f27a45a
# 2  91b7d2311527f5c2b63a65ca98d21d9c92485149
# 3  caabf9cbdf96eb1410295a673e953d304391bfbb
# 4  3da746a7d9afcaa659088c8366ef6347fe6b53ea
# 5  5ed5e3fbd235a8046cd3b87f4a1aa51b856c8ec3
# 6  6394f51b120ceb3da5e7b53dd5167fc4cf80b514
# 7  98be9b2d558c17df8a13597195957a7c8587ddcd
# 8  57f68638739c3a1de8d9922b389d6ded39977012
# 9  20778c35c19d741cc182719de336d71e1a0b228e
#
#                                              article  \
# 0  Ever noticed how plane seats appear to be gett...
# 1  A drunk teenage boy had to be rescued by secur...
# 2  Dougie Freedman is on the verge of agreeing a ...
# 3  Liverpool target Neto is also wanted by PSG an...
# 4  Bruce Jenner will break his silence in a two-h...
# 5  This is the moment that a crew of firefighters...
# 6  The amount of time people spend listening to B...
# ...

# %%
validation_df = pd.read_csv("validation.csv.zip")
validation_df.head(10)
# Out:
#                                          id  \
# 0  61df4979ac5fcc2b71be46ed6fe5a46ce7f071c3
# 1  21c0bd69b7e7df285c3d1b1cf56d4da925980a68
# 2  56f340189cd128194b2e7cb8c26bb900e3a848b4
# 3  00a665151b89a53e5a08a389df8334f4106494c2
# 4  9f6fbd3c497c4d28879bebebea220884f03eb41a
# 5  ce7460d21ce2336a0a8ee5812edd8b785b71811f
# 6  b5febe3ebb819b1743b6718288b2d93a41193c4f
# 7  4a039636bd3f339eceb4f46312d1b2daa4fa3cf0
# 8  7bd8693d22bab10ae7ee5422831d16baa251c8fa
# 9  6fec76621340051518f7acb6280873c3c857eba5
#
#                                              article  \
# 0  Sally Forrest, an actress-dancer who graced th...
# 1  A middle-school teacher in China has inked hun...
# 2  A man convicted of killing the father and sist...
# 3  Avid rugby fan Prince Harry could barely watch...
# 4  A Triple M Radio producer has been inundated w...
# 5  The team with the lowest transfer outlay this ...
# 6  A team from a Spanish university . has discove...
# ...

# %%
sample = train_df.sample()
print('**Article:')
print(sample.article.values)
print()
print('-'*50)
print()
print('**Highlight:')
print(sample.highlights.values)
# Out:
# **Article:
# ...

# %%
len(train_df)
# Out:
# 287113

# %%
len(test_df)
# Out:
# 11490

# %%
len(validation_df)
# Out:
# 13368

# %% [markdown]
# ### counting row & coloumn in each dataset

# %%
train_df.shape
# Out:
# (287113, 3)

# %%
test_df.shape
# Out:
# (11490, 3)

# %%
validation_df.shape
# Out:
# (13368, 3)

# %%
train_df.describe()
# Out:
#                                               id  \
# count                                     287113
# unique                                    287113
# top     0001d1afc246a7964130f43ae940af6bc6c57f01
# freq                                           1
#
#                                                   article  \
# count                                              287113
# unique                                             284005
# top     (CNN) -- Dubai could lose its place on the Wom...
# freq                                                    3
#
#                                                highlights
# count                                              287113
# unique                                             282197
# top     This page includes the show Transcript and the...
# freq                                                   83

# %%
train_df.duplicated(subset= ['article', 'highlights']).sum()
# Out:
# 3098

# %% [markdown]
# ## drop duplicate data

# %%
train_df = train_df.drop_duplicates(subset= ['article', 'highlights'])
train_df.shape
# Out:
# (284015, 3)

# %%
def article_len(row):
    return len(row['article'].split())

def highlights_len(row):
    return len(row['highlights'].split())

train_df['article_len'] = train_df.apply(lambda r: article_len(r), axis= 1)
train_df['highlights_len'] = train_df.apply(lambda r: highlights_len(r), axis= 1)

#for warning i imported below libraries
import warnings 
warnings.filterwarnings('ignore')
# Out:
# C:\Users\vidne\AppData\Local\Temp/ipykernel_13552/4231591324.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['article_len'] = train_df.apply(lambda r: article_len(r), axis= 1)
# C:\Users\vidne\AppData\Local\Temp/ipykernel_13552/4231591324.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['highlights_len'] = train_df.apply(lambda r: highlights_len(r), axis= 1)

# %%
from nltk.tokenize import sent_tokenize
text = """"The Hunger Games" is on track to rake in more than $80 million opening weekend, reports say .
Director: "I'm a fan first. ... I didn't have any desire to rework (the story) in any major way"
Casting the right actors is imperative when adapting a novel for the screen, critic says ."""

# %%
print(sent_tokenize(text))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13552/1190964772.py in <module>
# ----> 1 print(sent_tokenize(text))
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#     108
#
# ~\anaconda3\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# ~\anaconda3\lib\site-packages\nltk\data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# ...

# %%
# !pip install nltk

# %%
nltk.download('punkt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13552/1296283623.py in <module>
# ----> 1 nltk.download('punkt')
#
# NameError: name 'nltk' is not defined

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10054] An
# [nltk_data]     existing connection was forcibly closed by the remote
# [nltk_data]     host>
# False

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\vidne\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\vidne\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\vidne\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\vidne\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\vidne\AppData\Roaming\nltk_data...
# ...

# %%
from nltk.tokenize import sent_tokenize
text = """"The Hunger Games" is on track to rake in more than $80 million opening weekend, reports say .
Director: "I'm a fan first. ... I didn't have any desire to rework (the story) in any major way"
Casting the right actors is imperative when adapting a novel for the screen, critic says ."""

# %%
print(sent_tokenize(text))
# Out:
# ['"The Hunger Games" is on track to rake in more than $80 million opening weekend, reports say .', 'Director: "I\'m a fan first.', '...', 'I didn\'t have any desire to rework (the story) in any major way"\nCasting the right actors is imperative when adapting a novel for the screen, critic says .']

# %%
train_df.head()
# Out:
#                                          id  \
# 0  0001d1afc246a7964130f43ae940af6bc6c57f01
# 1  0002095e55fcbd3a2f366d9bf92a95433dc305ef
# 2  00027e965c8264c35cc1bc55556db388da82b07f
# 3  0002c17436637c4fe1837c935c04de47adb18e9a
# 4  0003ad6ef0c37534f80b55b4235108024b407f0b
#
#                                              article  \
# 0  By . Associated Press . PUBLISHED: . 14:11 EST...
# 1  (CNN) -- Ralph Mata was an internal affairs li...
# 2  A drunk driver who killed a young woman in a h...
# 3  (CNN) -- With a breezy sweep of his pen Presid...
# 4  Fleetwood are the only team still to have a 10...
#
#                                           highlights  article_len  \
# 0  Bishop John Folda, of North Dakota, is taking ...          198
# 1  Criminal complaint: Cop used his role to help ...          392
# 2  Craig Eccleston-Todd, 27, had drunk at least t...          808
# 3  Nina dos Santos says Europe must be ready to a...          531
# ...

# %%
train_df.id.nunique()
# Out:
# 284015

# %%
train_df = train_df.drop('id', axis= 1)
train_df.head(10)
# Out:
#                                              article  \
# 0  By . Associated Press . PUBLISHED: . 14:11 EST...
# 1  (CNN) -- Ralph Mata was an internal affairs li...
# 2  A drunk driver who killed a young woman in a h...
# 3  (CNN) -- With a breezy sweep of his pen Presid...
# 4  Fleetwood are the only team still to have a 10...
# 5  He's been accused of making many a fashion fau...
# 6  By . Daily Mail Reporter . PUBLISHED: . 01:15 ...
# 7  By . Daily Mail Reporter . This is the moment ...
# 8  There are a number of job descriptions waiting...
# 9  Canberra, Australia (CNN) -- At first glance, ...
#
#                                           highlights  article_len  \
# 0  Bishop John Folda, of North Dakota, is taking ...          198
# 1  Criminal complaint: Cop used his role to help ...          392
# 2  Craig Eccleston-Todd, 27, had drunk at least t...          808
# 3  Nina dos Santos says Europe must be ready to a...          531
# ...

# %%
train_df.describe()
# Out:
#          article_len  highlights_len
# count  284015.000000   284015.000000
# mean      692.231660       51.649240
# std       336.649158       21.342314
# min         8.000000        4.000000
# 25%       443.000000       38.000000
# 50%       632.000000       49.000000
# 75%       877.000000       60.000000
# max      2347.000000     1296.000000
